# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, YouTubeVideo, HTML
import IPython
import webbrowser
from ipywidgets import Layout

# %%
# %%html
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0 0 0 0px;
# }
# .back{
#     height: 130px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
# }
# .subnav {
#   float: left;
#   overflow: hidden;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# .navbar_0 a:hover, .subnav:hover .subnavbtn {
#   position:relative;
#   display:inlije-block;
#   overflow:visible;
#   background-color: #F48B34;
# }
# .subnav-content {
#   display: none;
#   position: absolute;
#   left: 0;
#   background-color: #263133;
#   width: 100%;
#   z-index: 1;
#     border-style: solid;
#   border-color: white;
#     border-width:1px;
# }
# .subnav-content a {
#   float: left;
#   overflow:visible;
#   color: white;
#   text-decoration: none;
# }
# .subnav-content a:hover {
#   background-color: #F48B34;
#   color: black;
# }
# .subnav:hover .subnav-content {
#   display: block;
# }
# </style>
# </head>
#
#
#
#
#
# <style>
# .content_0 {
#   display: flex;
#   text-align: center;
#   vertical-align: middle;
# }
#
#
# .icon-container {
#   margin-top: 0px;
#   width: 100%;
#   height: 70px;
# }
#
# .icon {
#   cursor: pointer;
#   position: relative;
#   display: inline-block;
#   width: 45px;
#   height: 45px;
#   margin-left: 12px;
#   margin-right: 12px;
#   border-radius: 30px;
#   overflow: hidden;
#   background-color:white;
# }
# .icon::before, .icon::after {
#   content: "";
#   position: absolute;
#   top: 0;
#   left: 0;
#   height: 100%;
#   width: 100%;
#   transition: all 0.25s ease;
#   border-radius: 30px;
# }
# .icon i {
#   position: relative;
#   color: #263133;
#   font-size: 24px;
#   margin-top: 10px;
#   transition: all 0.25s ease;
# }
#
# .icon-fill::before {
#   transition-duration: 0.7s;
# }
# .icon-fill:hover::before {
#   box-shadow: inset 0 0 0 60px #F48B34;
#
# }
# </style>
#
#
#
#
#
# <body>
# <div class=back>
# <img src="Figures/v2.svg.png" alt="Vertica logo" width="300">
# </div>
# <div class="navbar_0">
#
#   <div class="subnav">
#     <div class="content_0">
#       <div class="icon-container">
#         <div class="icon icon-fill" onclick="window.location.href = 'http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb';"><i class="fa fa-home"></i></div>
#       </div>
#     </div>
#   </div>
#
#   <div class="subnav">
#     <button class="subnavbtn">Courses <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb">Data Science Essentials</a>
#
#     </div>
#   </div>
#   <div class="subnav">
#     <button class="subnavbtn">Documentation <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/">vDataFrame</a>
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/plot.php">Plots</a>
#       <a href="https://www.vertica.com/python/workshop/ml/">Machine Learning</a>
#     </div>
#   </div>
#     <div class="subnav">
#     <button class="subnavbtn">Quick Examples <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Examples/Inference%20of%20geopolitical%20data/Example_Data_Wrangling_And_Analysis.ipynb">Geopolitical Analysis</a>
#       <a href="https://www.vertica.com/python/examples/">Business Applications</a>
#
#     </div>
#   </div>
#   <a href="https://www.vertica.com/contact-us/">Contact</a>
# </div>
# </body>
# Out:
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0 0 0 0px;
# }
# .back{
#     height: 130px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
# }
# .subnav {
#   float: left;
#   overflow: hidden;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# .navbar_0 a:hover, .subnav:hover .subnavbtn {
#   position:relative;
# ...

# %%
# %%html
# <!--Styles for the buttons displayed-->
# <style>
# .buttonstyle { color:white ;
#                      background-color:#263133;
#                      font-size:120%}
# .popstyle{
#     background-color:#ECEEEF;
#     border-radius:10px;
#     padding:10px;
#     margin:0 0 0 20px
# }
# .highlights_style{
#     padding:5px 3px 5px 3px;
#     border-radius:6px;
# }
# .button_0_position_style{
#     border-radius:3px;
#     margin-top:20px;
# }
# .button_0_style{
#     color:white;
#     background-color:#F48B34;
#     border-radius:3px;
#     font-size:16px;
# }
# .highlight_each_style{
# appearance: none;
# background-color: #FAFBFC;
# border: 1px solid rgba(27, 31, 35, 0.15);
# border-radius: 6px;
# box-shadow: rgba(27, 31, 35, 0.04) 0 1px 0, rgba(255, 255, 255, 0.25) 0 1px 0 inset;
# box-sizing: border-box;
# color: #F48B34;
# display: inline-block;
# font-family: -apple-system, system-ui, "Segoe UI", Helvetica, Arial, sans-serif, "Apple Color Emoji", "Segoe UI Emoji";
# font-size: 14px;
# font-weight: 500;
# line-height: 20px;
# list-style: none;
# padding: 1px 3px 1px 4px;
# position: relative;
# -webkit-user-select: none;
# vertical-align: middle;
# white-space: nowrap;
# word-wrap: break-word;
# }</style>
# Out:
# <!--Styles for the buttons displayed-->
# <style>
# .buttonstyle { color:white ;
#                      background-color:#263133;
#                      font-size:120%}
# .popstyle{
#     background-color:#ECEEEF;
#     border-radius:10px;
#     padding:10px;
#     margin:0 0 0 20px
# }
# .highlights_style{
#     padding:5px 3px 5px 3px;
#     border-radius:6px;
# }
# .button_0_position_style{
#     border-radius:3px;
#     margin-top:20px;
# }
# .button_0_style{
#     color:white;
#     background-color:#F48B34;
#     border-radius:3px;
#     font-size:16px;
# }
# .highlight_each_style{
# appearance: none;
# background-color: #FAFBFC;
# border: 1px solid rgba(27, 31, 35, 0.15);
# border-radius: 6px;
# box-shadow: rgba(27, 31, 35, 0.04) 0 1px 0, rgba(255, 255, 255, 0.25) 0 1px 0 inset;
# box-sizing: border-box;
# color: #F48B34;
# display: inline-block;
# font-family: -apple-system, system-ui, "Segoe UI", Helvetica, Arial, sans-serif, "Apple Color Emoji", "Segoe UI Emoji";
# ...

# %% [markdown]
# <br>

# %%
# Video, Brief Description & Highlights
# PLEASE UPDATE

# Add the link to Video here
f="Figures/Video_1.mp4"
vid=widgets.Video.from_file(f,
                            width=800, 
                            #height=200
                           )

text_0 = widgets.HTML(value="<h2>Briefly</h2>")

# Add the Welcome message between the ' "" '
text_1 = widgets.HTML(value="\
                      Welcome! \
                      Data Science Essentials is a course that is first of the many to come in our vertica-demo lesson series. \
                      It covers the basics of data science for anyone with just a superficial understanding of data science concepts.\
                      Along with teaching basic concepts, we highlight the efficacy of some of the convenient VerticaPy functions.\
                      This can be the first step for anyone to learn about VerticaPy and Vertica in general.")

# Edit the Highlights. Feel free to add more. 
highlight_1 = widgets.HTML(
    value="<b>Intro to Data Science</b>"
    )
highlight_2 = widgets.HTML(
    value="<b>Regression</b>"
    )
highlight_3 = widgets.HTML(
    value="<b>Classification</b>"
    )
highlight_4 = widgets.HTML(
    value="<b>Data Manipulation</b>"
    )
highlight_1.add_class('highlight_each_style')
highlight_2.add_class('highlight_each_style')
highlight_3.add_class('highlight_each_style')
highlight_4.add_class('highlight_each_style')

button_0 = widgets.Button(
    description='Let''s Start !',
    layout=Layout(align_self= 'center')
)

button_0.add_class('button_0_style')
button_0_box=widgets.VBox([button_0])
button_0_box.add_class('button_0_position_style')

# Edit the URL so that it leads to the first Module's Page
output = widgets.Output()
def on_button_clicked(b):
    with output:
        URL="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Overview%20of%20Data%20science/Essentials_OverviewOfDataScience.ipynb"
        webbrowser.open(URL)
        #print("Button clicked.")

button_0.on_click(on_button_clicked)

# Add any new highlights created below
highlights=widgets.HBox([highlight_1,highlight_2,highlight_3,highlight_4],layout=Layout(display='flex',flex_flow='row',justify_content='center',))

highlights.add_class('highlights_style')
vbox_text_0 = widgets.VBox([text_0, text_1,highlights,button_0_box])
vbox_text_0.add_class('popstyle')
hbox_line2 = widgets.HBox([vid,vbox_text_0])
display(hbox_line2)

# %%
# The Time and Difficulty Level

file = open("Figures/timer.svg.png", "rb")
image = file.read()
image_headline_0 = widgets.Image(
                    value=image,
                    format='png',layout=widgets.Layout(width='40px', height='100%',margin='0 0 0 0px')
                )

file = open("Figures/puzzle.svg.png", "rb")
image = file.read()
image_headline_1 = widgets.Image(
                    value=image,
                    format='png',layout=widgets.Layout(width='40px', height='100%',margin='0 0 0 0px')
                )

# Edit the time requirement here
text_0 = widgets.HTML(value="<font size='2'><b>6 hours</font>",
                      layout=widgets.Layout()
                     )

# Edit the difficulty level here
text_1 = widgets.HTML(value="<font size='2'><b>Easy</font>",
                      layout=widgets.Layout()
                     )

hbox_line2_1 = widgets.VBox([image_headline_0,text_0],layout=Layout(align_items="center",padding="0 0 0 10px"))
hbox_line2_2 = widgets.VBox([image_headline_1,text_1],layout=Layout(align_items="center",padding="0 0 0 20px"))
hbox_line2 = widgets.HBox([hbox_line2_1,hbox_line2_2])
                         
display(hbox_line2)

# %% [markdown]
# <!--Edit the prerequisites here-->
#
# <div style="border-radius:6px;font-family:calibri;background-color:#ECEEEF;padding:8px;width:800px">
#     <p style="padding:6px"><font size=4><b> Prerequisites </b></font><br>This is an introductory course with no particular prerequisities. But it will be good to brush up the following:
# <br>
# ✔ Python programming <br>

# %% [markdown]
# <!--Edit the Goals here-->
# <div style="border-radius:6px;font-family:calibri;background-color:#ECEEEF;padding:8px;width:800px">
#     <p style="padding:6px"><font size=4><b> Goals </b></font><br>We want to familiarize you with data science and VerticaPy. At the end of this course you shall know:
# <br>
# 🎯 General understanding of Data Science <br>
# 🎯 Basic data operations <br>
# 🎯 Linear regression<br>
# 🎯 Binary and multinomial classification<br>
# 🎯 Wide variety of efficient VerticaPy functions<br></l></div>

# %% [markdown]
# ### Modules
# ***

# %%
# %%html
# <!--Edit the hyperlinks of the modules-->
#
# <!DOCTYPE html>
# <html>
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# .accordion {
#   background-color: #F48B34;
#   color: white;
#   cursor: pointer;
#   padding: 18px;
#   width: 20%;
#   border: none;
#   text-align: left;
#   outline: none;
#   font-size: 15px;
#   transition: 0.4s;
# }
#
# .active, .accordion:hover {
#   background-color: #ccc;
# }
#
# .accordion:after {
#   content: '\002B';
#   color: #777;
#   font-weight: bold;
#   float: right;
#   margin-left: 5px;
# }
#
# .active:after {
#   content: "\2212";
# }
#
#
# .panel {
#   padding: 0 18px;
#   display: none;
#   background-color: white;
#   overflow: hidden;
# }
# </style>
# </head>
# <body>
#
#
#
# <button class="accordion"><font size='4'>Overview of Data Science</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Overview%20of%20Data%20science/Essentials_OverviewOfDataScience.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Overview%20of%20Data%20science/Essentials_OverviewOfDataScience_Overview.ipynb">
#     Overview</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Basic Data Ingestion</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Ingestion/Essentials_DataIngestion.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Ingestion/DataIngestion.ipynb">
#     Lesson</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Ingestion/Application.ipynb">
#     Application</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Basic Data Exploration</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Exploration/Essentials_DataExploration.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Exploration/Essentials_DataExploration_Lesson.ipynb">
#     Data Exploration Application</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Basic Data Preparation</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Preparation/Essentials_DataPreparation.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Preparation/Essentials_DataPreparation_Loading.ipynb">
#     Loading</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Data%20Preparation/Essentials_DataPreparation_Prep.ipynb">
#     Prepartion</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Linear Regression</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Linear%20Regression/Essentials_LinearRegression.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Linear%20Regression/Essentials_LinearRegression_Theory.ipynb">
#     Theory</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Linear%20Regression/Essentials_LinearRegression_Example.ipynb">
#     Application</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Linear%20Regression/Essentials_LinearRegression_Exercise.ipynb">
#     Exercise</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Classification</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification.ipynb">
#     Main Page</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_LogisticRegression.ipynb">
#     Binary Classificaiton</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_LogisticRegression_Example.ipynb">
#     Binary Classificaiton - Example</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_RandomForest.ipynb">
#     Multinomial Classificaiton</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_RandomForest_Example.ipynb">
#     Multinomial Classificaiton - Example</a></p>
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_Exercise.ipynb">
#     Exercise</a></p>
# </div>
#
# <button class="accordion"><font size='4'>Project</button></font>
# <div class="panel">
#     <p><a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Module%20-%20Project/Essentials_Project.ipynb">
#     Main Page</a></p>
# </div>
#
# <script>
# var acc = document.getElementsByClassName("accordion");
# var i;
#
# for (i = 0; i < acc.length; i++) {
#   acc[i].addEventListener("click", function() {
#     this.classList.toggle("active");
#     var panel = this.nextElementSibling;
#     if (panel.style.display === "block") {
#       panel.style.display = "none";
#     } else {
#       panel.style.display = "block";
#     }
#   });
# }
# </script>
#
# </body>
# </html>
