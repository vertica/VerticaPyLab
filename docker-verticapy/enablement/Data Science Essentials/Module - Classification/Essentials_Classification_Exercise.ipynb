# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from ipywidgets import Layout

# %%
# %%html
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0px 0px 0px 0px;
# }
# .back{
#     height: 90px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
#   z-index: 2;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
#   z-index: 2;
# }
# .subnav {
#   float: left;
#   display:inline-block;
#   overflow: visible;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# .navbar_0 a:hover, .subnav:hover .subnavbtn {
#   position:relative;
#   display:inline-block;
#   overflow:visible;
#   background-color: #1a6aff;
# }
# .subnav-content {
#   display: none;
#   overflow: visible;
#   position: absolute;
#   left: 0;
#   background-color: #263133;
#   width: 100%;
#   z-index: 3;
#   border-style: solid;
#   border-color: white;
#   border-width:1px;
#
# }
# .subnav-content a {
#   float: left;
#   overflow:visible;
#   color: white;
#   text-decoration: none;
# }
# .subnav-content a:hover {
#   background-color: #1a6aff;
#   color: black;
# }
# .subnav:hover .subnav-content {
#   display: block;
# }
# .sticky {
#   position: fixed;
#   top: 0;
#   width: 100%;
#   overflow: visible;
# }
#
# .sticky + .content {
#   padding-top: 10px;
# }
# .sticky_2 {
#   position: relative;
#   top: 0;
#   width: 100%;
# }
# </style>
# </head>
#
# <style>
# .content_0 {
#   display: flex;
#   text-align: center;
#   vertical-align: middle;
# }
#
#
# .icon-container {
#   margin-top: 0px;
#   width: 100%;
#   height: 70px;
# }
#
# .icon {
#   cursor: pointer;
#   position: relative;
#   display: inline-block;
#   width: 45px;
#   height: 45px;
#   margin-left: 12px;
#   margin-right: 12px;
#   border-radius: 30px;
#   overflow: hidden;
#   background-color:white;
# }
# .icon::before, .icon::after {
#   content: "";
#   position: absolute;
#   top: 0;
#   left: 0;
#   height: 100%;
#   width: 100%;
#   transition: all 0.25s ease;
#   border-radius: 30px;
# }
# .icon i {
#   position: relative;
#   color: #263133;
#   font-size: 24px;
#   margin-top: 10px;
#   transition: all 0.25s ease;
# }
#
# .icon-fill::before {
#   transition-duration: 0.7s;
# }
# .icon-fill:hover::before {
#   box-shadow: inset 0 0 0 60px #1a6aff;
#
# }
# </style>
#
#
#
#
#
# <body>
# <div class=back>
# <img src="Figures/v2.svg.png" alt="Vertica logo" width="350">
# </div>
# <div class="navbar_0" id="navbar_top">
#
#   <div class="subnav">
#     <div class="content_0">
#       <div class="icon-container">
#         <div class="icon icon-fill" onclick="window.location.href = '/voila/render/demos/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb';"><i class="fa fa-home"></i></div>
#       </div>
#     </div>
#   </div>
#
#   <div class="subnav">
#     <button class="subnavbtn">Courses <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="/voila/render/demos/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb">Data Science Essentials</a>
#
#     </div>
#   </div>
#   <div class="subnav">
#     <button class="subnavbtn">Documentation <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/">vDataFrame</a>
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/plot.php">Plots</a>
#       <a href="https://www.vertica.com/python/workshop/ml/">Machine Learning</a>
#     </div>
#   </div>
#     <div class="subnav">
#     <button class="subnavbtn">Quick Examples <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="/voila/render/demos/enablement/Examples/Inference%20of%20geopolitical%20data/Example_Data_Wrangling_And_Analysis.ipynb">Geopolitical Analysis</a>
#       <a href="https://www.vertica.com/python/examples/">Business Applications</a>
#
#     </div>
#   </div>
#   <a href="https://www.vertica.com/contact-us/">Contact</a>
# </div>
# </body>
# Out:
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0px 0px 0px 0px;
# }
# .back{
#     height: 130px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
#   z-index: 2;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
#   z-index: 2;
# }
# .subnav {
#   float: left;
#   display:inline-block;
#   overflow: visible;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# ...

# %%
# %%html
# <!--Style for correct and incorrect prompts-->
# <style>
#
# .correct-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: green;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(25,163,97,0.75);
#   padding:5px;
# }
# .incorrect-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: red;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(255, 0, 130, 0.5);
#   padding:5px;
# }
# </style>

# %%
# Defining a function for multiple choice widgets

def create_multipleChoice_widget(options, correct_answer):
    if correct_answer not in options:
        options.append(correct_answer)
    
    correct_answer_index = options.index(correct_answer)
    
    radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.RadioButtons(
        options = radio_options,
        description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
#    with description_out:
#        print(description)
        
    feedback_out = widgets.Output()

    def check_selection(b):
        a = int(alternativ.value)
        if a==correct_answer_index:
            s = widgets.HTML('<div class="correct-prompt">Correct!</div>')
        else:
            s = widgets.HTML('<div class="incorrect-prompt">Try Again!</div>')
        with feedback_out:
            clear_output()
            display(s)
        return
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])

def create_numeric_widget(correct_answer):
    
    #correct_answer_index = options.index(correct_answer)
    
    #radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.Text(
        #options = radio_options,
        #description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
#    with description_out:
#        print(description)
        
    feedback_out = widgets.Output()

    def check_selection(b):
        try:
            a = int(alternativ.value)
        except ValueError:
            a = float(alternativ.value)
        if a==correct_answer:
            s = widgets.HTML('<div class="correct-prompt">Correct!</div>')
        else:
            s = widgets.HTML('<div class="incorrect-prompt">Try Again!</div>')
        with feedback_out:
            clear_output()
            display(s)
        return
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])

# %%
# %%html
# <!--Module Button-->
#
# <style>
# .moduler{
#     box-shadow: 0px 15px 10px -15px #1a6aff;
#     font-size:30px;
#     color: blue;
# }
#     </style>
#
# <div class="moduler">
#   <a href="/voila/render/demos/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification.ipynb">Classification</a>
# </div>

# %% [markdown]
# ## Exercise

# %%
# %%html
# <!--Time required-->
# <i class="fas fa-clock" style='color:#1a6aff;font-size:18px;'></i> 20 mins
# Out:
# <!--Time required-->
# <i class="fas fa-clock" style='color:#F48B34;font-size:18px;'></i> 20 mins

# %% [markdown]
# These exercises ask you to apply to data science problems what you have learned about classification and VerticaPy.

# %% [markdown]
# ***

# %% [markdown]
# <a id='h1_cell'></a>
# ### Multi-class Classification
#
# The following exercises use [Customer Segementation](https://www.kaggle.com/datasets/abisheksudarshan/customer-segmentation) dataset.

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 1: </b> How many classes does the customer category have?</font>")
Q1 = create_multipleChoice_widget(['3','6','5','4'],'4')
display(widgets.VBox([text_1,Q1]))

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 2: </b> How many missing (empty/NULL) values are in each of the following columns: Ever_Married, Graduated, and Family_Size?</font>")
Q2 = create_multipleChoice_widget(['140 + 74 + 316','40 + 74 + 216','200 + 33 + 75'],'140 + 74 + 316')
display(widgets.VBox([text_1,Q2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 text_1 = widgets.HTML(value="<font size='3'><b> Question 1: </b> How many empty/NULL values are there in total from each of the following columns: Ever_Married, Graduated, and Family_Size?</font>")
#       2 Q1 = create_multipleChoice_widget(['140 + 74 + 316','40 + 74 + 216','200 + 33 + 75'],'140 + 74 + 316')
#       3 display(widgets.VBox([text_1,Q1]))
#
# NameError: name 'widgets' is not defined

# %% [markdown]
# Use the `dropna()` method to drop the missing values in the above three columns:
#
# ```Python
# data["Column"].dropna()
# ```

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 3: </b> Which other column has missing values? </font>")
Q3 = create_multipleChoice_widget(['ID','Gender','Work_Experience'],'Work_Experience')
display(widgets.VBox([text_1,Q3]))

# %% [markdown]
# Another way of handling missing values is by imputing them. This method replaces missing data with an estimated value.

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 4: </b> Which other columns can we use to impute the missing values in the above mentioned column? </font>")
Q4 = create_multipleChoice_widget(['ID + Gender','Age + Gender + Spending Score','Age + Graduated + Spending Score','Work_Experience + Gender + Spending Score'],'Age + Graduated + Spending Score')
display(widgets.VBox([text_1,Q4]))

# %% [markdown]
# Use the `fillna()` method to impute the missing values:
# ```Python
# data["Column To Impute"].fillna(method = "avg", by = List of Columns)
# ```

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 5: </b> After removing the missing values and imputing, does the data look balanced in terms of the classes for Segmentation?</font>")
Q5 = create_multipleChoice_widget(['Perfectly','Almost','Not at all'],'Almost')
display(widgets.VBox([text_1,Q5]))

# %% [markdown]
# Build a random forest classifier using the default settings:
# ```Python
# from verticapy.learn.ensemble import RandomForestClassifier
# model = RandomForestClassifier("RF_customer")
# model.fit(data, data.get_columns(["Segmentation"]), "Segmentation")
# ```

# %%
text_2 = widgets.HTML(value="<font size='3'><b> Question 6: </b> What is the precision for class A (to one decimal place)?</font>")
Q2 = create_numeric_widget(0.4)
display(widgets.VBox([text_2,Q2]))

# %% [markdown]
# Increasing the maximum allowed depth sometimes improves results:
#
# ```Python
# model=RandomForestClassifier("RF_new",
#                        max_depth= 18,
#                             )
# model.fit(data, data.get_columns(["Segmentation"]), "Segmentation")
# ```

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 7: </b> What is the new precision for class A?</font>")
Q5 = create_multipleChoice_widget(['0.4-0.5','0.6-0.7','0.8-0.9'],'0.8-0.9')
display(widgets.VBox([text_1,Q5]))

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 7: </b> Which is the most important feature?</font>")
Q5 = create_multipleChoice_widget(['Age','Famile_Size','Spending_Score'],'Age')
display(widgets.VBox([text_1,Q5]))

# %% [markdown]
# ***

# %% [markdown]
# <a id='h1_cell'></a>
# ### Binary-class Classification
#
# The following exercises use the [Heart Disease](https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset) dataset:

# %%
text_2 = widgets.HTML(value="<font size='3'><b> Question 1: </b> What is the precision (to one decimal place)?</font>")
Q2 = create_numeric_widget(0.9)
display(widgets.VBox([text_2,Q2]))

# %%
text_2 = widgets.HTML(value="<font size='3'><b> Question 2: </b> What is the cutoff (to one decimal)?</font>")
Q2 = create_numeric_widget(0.5)
display(widgets.VBox([text_2,Q2]))

# %% [markdown]
# Does increasing the cutoff improve accuracy?
# ```python
# model.classification_report(cutoff=0.7)
# ```

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 3: </b> Does the <i>accuracy</i> (not precision) increase?</font>")
Q5 = create_multipleChoice_widget(['Yes','No','Stays the same'],'No')
display(widgets.VBox([text_1,Q5]))

# %%
text_1 = widgets.HTML(value="<font size='3'><b> Question 4: </b> Which is the least important feature?</font>")
Q5 = create_multipleChoice_widget(['caa','fbs','restecg'],'fbs')
display(widgets.VBox([text_1,Q5]))

# %%
# %%javascript
# // When the user scrolls the page, execute myFunction
# window.onscroll = function() {myFunction()};
#
# // Get the navbar
# var navbar = document.getElementById("navbar_top");
#
# // Get the offset position of the navbar
# var sticky = navbar.offsetTop;
#
# // Add the sticky class to the navbar when you reach its scroll position. Remove "sticky" when you leave the scroll position
# function myFunction() {
#   if (window.pageYOffset >= sticky+140) {
#     navbar.classList.add("sticky")
#   } else {
#     navbar.classList.remove("sticky");
#   }
#   if (window.pageYOffset <= sticky) {
#     navbar.classList.remove("sticky");
#   }
# }

# %% [markdown]
# <html>
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# a {
#   text-decoration: none;
#   display: inline-block;
#   padding: 8px 16px;
# }
#
# a:hover {
#   background-color: #ddd;
#   color: black;
# }
#
# .previous {
#   background-color: #f1f1f1;
#   color: black;
# }
#
# .next {
#   background-color: #1a6aff;
#   color: white;
# }
#
# .round {
#   border-radius: 50%;
# }
# </style>
# </head>
# <body>
#
# <a href="/voila/render/demos/enablement/Data%20Science%20Essentials/Module%20-%20Classification/Essentials_Classification_RandomForest_Example.ipynb" font-size= 40px class="previous round">&#8249;</a>
# <a href="/voila/render/demos/enablement/Data%20Science%20Essentials/Module%20-%20Project/Essentials_Project.ipynb" class="next round">&#8250;</a>
#
# </body>
# </html>

# %% [markdown]
# ***

# %% [markdown]
# <font style="font-family:Calibri"> Author Name: Umar Farooq Ghumman
# <br>
# Author Contact: umarfarooq.ghumman@vertica.com</font>

# %% [markdown]
# ### Resources
#
# - [<font size='2'>Customer Dataset on Kaggle</font>](https://www.kaggle.com/datasets/abisheksudarshan/customer-segmentation)
#
# - [<font size='2'>Heart Dataset on Kaggle</font>](https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset)
