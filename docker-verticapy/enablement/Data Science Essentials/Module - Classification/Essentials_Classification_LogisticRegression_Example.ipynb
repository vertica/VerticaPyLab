# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from ipywidgets import Layout

# %%
# %%html
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0 0 0 0px;
# }
# .back{
#     height: 130px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
# }
# .subnav {
#   float: left;
#   overflow: hidden;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# .navbar_0 a:hover, .subnav:hover .subnavbtn {
#   position:relative;
#   display:inlije-block;
#   overflow:visible;
#   background-color: #F48B34;
# }
# .subnav-content {
#   display: none;
#   position: absolute;
#   left: 0;
#   background-color: #263133;
#   width: 100%;
#   z-index: 1;
#     border-style: solid;
#   border-color: white;
#     border-width:1px;
# }
# .subnav-content a {
#   float: left;
#   overflow:visible;
#   color: white;
#   text-decoration: none;
# }
# .subnav-content a:hover {
#   background-color: #F48B34;
#   color: black;
# }
# .subnav:hover .subnav-content {
#   display: block;
# }
# </style>
# </head>
#
#
#
#
#
# <style>
# .content_0 {
#   display: flex;
#   text-align: center;
#   vertical-align: middle;
# }
#
#
# .icon-container {
#   margin-top: 0px;
#   width: 100%;
#   height: 70px;
# }
#
# .icon {
#   cursor: pointer;
#   position: relative;
#   display: inline-block;
#   width: 45px;
#   height: 45px;
#   margin-left: 12px;
#   margin-right: 12px;
#   border-radius: 30px;
#   overflow: hidden;
#   background-color:white;
# }
# .icon::before, .icon::after {
#   content: "";
#   position: absolute;
#   top: 0;
#   left: 0;
#   height: 100%;
#   width: 100%;
#   transition: all 0.25s ease;
#   border-radius: 30px;
# }
# .icon i {
#   position: relative;
#   color: #263133;
#   font-size: 24px;
#   margin-top: 10px;
#   transition: all 0.25s ease;
# }
#
# .icon-fill::before {
#   transition-duration: 0.7s;
# }
# .icon-fill:hover::before {
#   box-shadow: inset 0 0 0 60px #F48B34;
#
# }
# </style>
#
#
#
#
#
# <body>
# <div class=back>
# <img src="Figures/v2.svg.png" alt="Vertica logo" width="300">
# </div>
# <div class="navbar_0">
#
#   <div class="subnav">
#     <div class="content_0">
#       <div class="icon-container">
#         <div class="icon icon-fill" onclick="window.location.href = 'http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb';"><i class="fa fa-home"></i></div>
#       </div>
#     </div>
#   </div>
#
#   <div class="subnav">
#     <button class="subnavbtn">Courses <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Data%20Science%20Essentials/Data_Science_Essentials.ipynb">Data Science Essentials</a>
#
#     </div>
#   </div>
#   <div class="subnav">
#     <button class="subnavbtn">Documentation <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/">vDataFrame</a>
#       <a href="https://www.vertica.com/python/documentation_last/vdataframe/plot.php">Plots</a>
#       <a href="https://www.vertica.com/python/workshop/ml/">Machine Learning</a>
#     </div>
#   </div>
#     <div class="subnav">
#     <button class="subnavbtn">Quick Examples <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="http://127.0.0.1:8889/voila/render/vertica-demo/docker-verticapy/enablement/Examples/Inference%20of%20geopolitical%20data/Example_Data_Wrangling_And_Analysis.ipynb">Geopolitical Analysis</a>
#       <a href="https://www.vertica.com/python/examples/">Business Applications</a>
#
#     </div>
#   </div>
#   <a href="https://www.vertica.com/contact-us/">Contact</a>
# </div>
# </body>
# Out:
# <!--The top Logo and the menu bar-->
#
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <style>
# body {
#   font-family: Arial, Helvetica, sans-serif;
#   margin: 0 0 0 0px;
# }
# .back{
#     height: 130px;
#     width: 100%;
#     background-color:#263133;
#     display: flex;
#     align-items: center;
# }
# .navbar_0 {
#   overflow: hidden;
#   background-color: #263133;
#   display: block;
# }
# .navbar_0 a {
#   float: left;
#   font-size: 16px;
#   color: white;
#   text-align: center;
#   padding: 14px 16px;
#   text-decoration: none;
#   overflow: visible;
#   display: inline-block;
# }
# .subnav {
#   float: left;
#   overflow: hidden;
# }
# .subnav .subnavbtn {
#   font-size: 16px;
#   border: none;
#   outline: none;
#   color: white;
#   padding: 14px 16px;
#   background-color: inherit;
#   font-family: inherit;
#   margin: 0;
#   position: relative;
# }
# .navbar_0 a:hover, .subnav:hover .subnavbtn {
#   position:relative;
#   display:inlije-block;
#   overflow:visible;
#   background-color: #F48B34;
# }
# .subnav-content {
#   display: none;
#   position: absolute;
#   left: 0;
#   background-color: #263133;
#   width: 100%;
#   z-index: 1;
#     border-style: solid;
#   border-color: white;
#     border-width:1px;
# }
# .subnav-content a {
#   float: left;
#   overflow:visible;
#   color: white;
#   text-decoration: none;
# }
# .subnav-content a:hover {
#   background-color: #F48B34;
#   color: black;
# }
# .subnav:hover .subnav-content {
#   display: block;
# }
# </style>
# </head>
#
#
#
#
#
# <style>
# .content_0 {
#   display: flex;
#   text-align: center;
#   vertical-align: middle;
# }
#
#
# .icon-container {
#   margin-top: 0px;
#   width: 100%;
#   height: 70px;
# }
#
# .icon {
#   cursor: pointer;
#   position: relative;
#   display: inline-block;
#   width: 45px;
#   height: 45px;
#   margin-left: 12px;
#   margin-right: 12px;
#   border-radius: 30px;
#   overflow: hidden;
#   background-color:white;
# }
# .icon::before, .icon::after {
#   content: "";
#   position: absolute;
#   top: 0;
#   left: 0;
#   height: 100%;
#   width: 100%;
#   transition: all 0.25s ease;
#   border-radius: 30px;
# }
# .icon i {
#   position: relative;
#   color: #263133;
#   font-size: 24px;
#   margin-top: 10px;
#   transition: all 0.25s ease;
# }
#
# .icon-fill::before {
#   transition-duration: 0.7s;
# }
# .icon-fill:hover::before {
#   box-shadow: inset 0 0 0 60px #F48B34;
#
# }
# </style>
#
#
#
#
#
# <body>
# <div class=back>
# <img src="Figures/v2.svg.png" alt="Vertica logo" width="300">
# </div>
# <div class="navbar_0">
#
#   <div class="subnav">
#     <div class="content_0">
#       <div class="icon-container">
#         <div class="icon icon-fill" onclick="window.location.href = 'http://localhost:8888/voila/render/Documents/GitHub/vertica-demo/docker-verticapy/enablement/Template/Course_Page_v1.ipynb';"><i class="fa fa-home"></i></div>
#       </div>
#     </div>
#   </div>
#
#   <div class="subnav">
#     <button class="subnavbtn">Courses <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="#">Course 1</a>
#       <a href="#">Course 2</a>
#       <a href="#">Course 3</a>
#     </div>
#   </div>
#   <div class="subnav">
#     <button class="subnavbtn">Documentation <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="#">Topic 1</a>
#       <a href="#">Topic 2</a>
#       <a href="#">Topic 3</a>
#     </div>
#   </div>
#     <div class="subnav">
#     <button class="subnavbtn">Quick Examples <i class="fa fa-caret-down"></i></button>
#     <div class="subnav-content">
#       <a href="#">Example 1</a>
#       <a href="#">Example 2</a>
#       <a href="#">Example 3 3</a>
#     </div>
#   </div>
#   <a href="#contact">Contact</a>
# </div>
# </body>

# %%
# %%html
# <!--Style for correct and incorrect prompts-->
# <style>
#
# .correct-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: green;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(25,163,97,0.75);
#   padding:5px;
# }
# .incorrect-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: red;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(255, 0, 130, 0.5);
#   padding:5px;
# }
# </style>
# Out:
# <!--Style for correct and incorrect prompts-->
# <style>
#
# .correct-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: green;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(25,163,97,0.75);
#   padding:5px;
# }
# .incorrect-prompt {
#   font-family: "Helvetica", "Arial", sans-serif;
#   display: inline-block;
#   font-size: 17px;
#   background-color: red;
#   color: #fff;
#   border-radius: 4px;
#   position: relative;
#   box-shadow: 0 2px 25px rgba(255, 0, 130, 0.5);
#   padding:5px;
# }
# </style>

# %%
# Defining a function for multiple choice widgets

def create_multipleChoice_widget(options, correct_answer):
    if correct_answer not in options:
        options.append(correct_answer)
    
    correct_answer_index = options.index(correct_answer)
    
    radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.RadioButtons(
        options = radio_options,
        description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
#    with description_out:
#        print(description)
        
    feedback_out = widgets.Output()

    def check_selection(b):
        a = int(alternativ.value)
        if a==correct_answer_index:
            s = widgets.HTML('<div class="correct-prompt">Correct!</div>')
        else:
            s = widgets.HTML('<div class="incorrect-prompt">Try Again!</div>')
        with feedback_out:
            clear_output()
            display(s)
        return
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])

def create_numeric_widget(correct_answer):
    
    #correct_answer_index = options.index(correct_answer)
    
    #radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.Text(
        #options = radio_options,
        #description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
#    with description_out:
#        print(description)
        
    feedback_out = widgets.Output()

    def check_selection(b):
        try:
            a = int(alternativ.value)
        except ValueError:
            a = float(alternativ.value)
        if a==correct_answer:
            s = widgets.HTML('<div class="correct-prompt">Correct!</div>')
        else:
            s = widgets.HTML('<div class="incorrect-prompt">Try Again!</div>')
        with feedback_out:
            clear_output()
            display(s)
        return
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])

# %%
# %%html
# <!--Module Button-->
#
# <style>
# .moduler{
#     box-shadow: 0px 15px 10px -15px #F48B34;
#     font-size:30px;
#     color: blue;
# }
#     </style>
#
# <div class="moduler">
#   <a href="http://localhost:8888/voila/render/Documents/GitHub/vertica-demo/docker-verticapy/enablement/Template/Module_Page_v1.ipynb">Classification</a>
# </div>
# Out:
# <!--Module Button-->
#
# <style>
# .moduler{
#     box-shadow: 0px 15px 10px -15px #F48B34;
#     font-size:30px;
#     color: blue;
# }
#     </style>
#
# <div class="moduler">
#   <a href="http://localhost:8888/voila/render/Documents/GitHub/vertica-demo/docker-verticapy/enablement/Template/Module_Page_v1.ipynb">Classification</a>
# </div>

# %% [markdown]
# ## Logistic Regression

# %%
# %%html
# <!--Time required-->
# <i class="fas fa-clock" style='color:#F48B34;font-size:18px;'></i> 15 mins
# Out:
# <!--Time required-->
# <i class="fas fa-clock" style='color:#F48B34;font-size:18px;'></i> 15 mins

# %% [markdown]
# ### Table of Contents
#
# - [Ingesting the data](#h1_cell)
# - [Data exploration](#h2_cell)
# - [Applying logistic regression](#h2_cell)

# %% [markdown]
# ### Covered in This Module
#
# - Application of ligstic regression using verticapy
# - Understanding the nuances of logistic regression
# - Interpreting the results of classficiation metrics

# %% [markdown]
# ***

# %% [markdown]
# <a id='h1_cell'></a>
# ### Ingesting data

# %% [markdown]
# This example uses the [Default](https://r-data.pmagunia.com/dataset/r-dataset-package-islr-default) dataset, which contains information about people and whether they defaulted on their credit card debt. More specifically, the dataset contains four features for each person:
# - Did the person default?
# - Is the person a student?
# - What is their balance?
# - What is their annual income?
#
# You can build a classification model based on the last three parameters. This model can then be used to predict if a person is likely to default on their credit card debt.
#
# To begin, load the data into VerticaPy:
#
# ```python
# import verticapy as vp
# data=vp.read_csv('Data/default_data.csv')
# ```

# %%
import verticapy as vp
data=vp.read_csv('Data/default_data.csv')

# %% [markdown]
# Examine the data:

# %%
data
# Out:
#        serial    default    student    credit_balance         income
# 1           1      False      False       729.5264952    44361.62507
# 2           2      False       True       817.1804066     12106.1347
# 3           3      False      False       1073.549164    31767.13895
# 4           4      False      False       529.2506047    35704.49394
# 5           5      False      False       785.6558829    38463.49588
# 6           6      False       True       919.5885305    7491.558572
# 7           7      False      False       825.5133305    24905.22658
# 8           8      False       True       808.6675043    17600.45134
# 9           9      False      False       1161.057854    37468.52929
# 10         10      False      False               0.0    29275.26829
# 11         11      False       True               0.0    21871.07309
# 12         12      False       True       1220.583753    13268.56222
# 13         13      False      False        237.045114    28251.69534
# 14         14      False      False       606.7423433    44994.55585
# 15         15      False      False       1112.968401    23810.17405
# 16         16      False      False       286.2325601    45042.41304
# 17         17      False      False               0.0    50265.31235
# 18         18      False       True       527.5401841    17636.53962
# 19         19      False      False       485.9368642    61566.10612
# 20         20      False      False       1095.072735    26464.63139
# 21         21      False      False       228.9525496     50500.1822
# 22         22      False      False       954.2617928    32457.50908
# 23         23      False      False       1055.956605    51317.88308
# 24         24      False      False       641.9843888    30466.10326
# 25         25      False      False       773.2117245    34353.31431
# 26         26      False      False       855.0085225    25211.33216
# 27         27      False      False       642.9997385     41473.5118
# 28         28      False      False       1454.863272    32189.09495
# 29         29      False      False       615.7042766    39376.39462
# 30         30      False       True       1119.569353    16556.07021
# 31         31      False      False       494.8162288    54384.78284
# 32         32      False       True       448.8806563    15799.47041
# 33         33      False       True       584.9048947    22429.93505
# 34         34      False      False       913.5871726     46907.2254
# 35         35      False       True       1423.938917    22634.48809
# 36         36      False       True       1499.724657    13190.65272
# 37         37      False      False       692.0341671    47806.61177
# 38         38      False      False       351.4534715    35087.48865
# 39         39      False      False       742.6276208    37864.82394
# 40         40      False      False       653.1184001     39489.5947
# 41         41      False      False       872.1386795    41787.56727
# 42         42      False      False       837.2626228    51471.77209
# 43         43      False      False       1151.630566    42917.46956
# 44         44      False       True       220.5556084    16872.94756
# 45         45      False       True        1690.23441    19052.57222
# 46         46      False      False       408.7729143    54206.93921
# 47         47      False      False       1238.610321    50066.68053
# 48         48      False      False        1228.30835    37408.50387
# 49         49      False      False       820.9192041    47746.54207
# 50         50      False      False       857.4851178    31688.34597
# 51         51      False      False       563.6181772    42641.25327
# 52         52      False       True       1282.972534    13120.63647
# 53         53      False       True       1505.782675    26557.14145
# 54         54      False       True       904.0402591    16882.30061
# 55         55      False      False               0.0    49956.58057
# 56         56      False       True       1294.497347    10464.32073
# 57         57      False       True       1275.550633    15887.46849
# 58         58      False      False       1536.594601    48766.90746
# 59         59      False      False       1332.522644    39143.13707
# 60         60      False      False       492.0797678     33379.0946
# 61         61      False      False       766.2343793    46478.29426
# 62         62      False      False       690.1272462    63432.98425
# 63         63      False      False               0.0    32481.54005
# 64         64      False      False       1480.655309    36866.15707
# 65         65      False      False        989.055597    45344.25132
# 66         66      False      False       1302.341835    33695.42623
# 67         67      False      False       1044.552343    54696.76598
# 68         68      False      False               0.0    43658.22772
# 69         69      False      False       866.0284364    38363.42163
# 70         70      False      False       690.8007924    48140.47134
# 71         71      False      False        597.757142    31577.61513
# 72         72      False      False       429.4854023     51311.2181
# 73         73      False      False       1398.156201    39644.94219
# 74         74      False       True       1578.064099    19886.49395
# 75         75      False      False       857.0690531    26655.68897
# 76         76      False       True        752.459946    16211.27579
# 77         77      False       True        774.738427    15193.73314
# 78         78      False      False       728.3732513    45131.71826
# 79         79      False      False       76.99129053    28392.09341
# 80         80      False      False       196.4569131    41346.78591
# 81         81      False       True       948.7479184    14297.61905
# 82         82      False      False       431.9208853    39369.88156
# 83         83      False      False       461.6381822    46221.21149
# 84         84      False      False       572.0157602    33046.31296
# 85         85      False      False       335.5681447    51258.44423
# 86         86      False      False       510.2375932    60397.71865
# 87         87      False       True       1005.161306    24038.65204
# 88         88      False       True       162.4544511    13241.75206
# 89         89      False      False       932.5331557    50537.46565
# 90         90      False       True       893.3304676    11905.68179
# 91         91      False      False       1332.782564    44495.16276
# 92         92      False      False       1404.383069    35043.10603
# 93         93      False       True       1148.965139    16578.19212
# 94         94      False      False       368.2234257    57596.82584
# 95         95      False      False       449.4666288    45950.66672
# 96         96      False      False       820.0171126    51584.65732
# 97         97      False       True       619.7518686    15750.62208
# 98         98      False      False       1047.718124    46416.97099
# 99         99      False      False       243.8413283    47193.88813
# 100       100      False      False       186.5003869    45430.55027
# Rows: 1-100 | Columns: 5

# %% [markdown]
# The `serial` column is just the row number, so it can be dropped:
# ```python
# data.drop('serial')
# ```

# %%
data.drop('serial')
# Out:
#        default    student    credit_balance         income
# 1        False      False       729.5264952    44361.62507
# 2        False       True       817.1804066     12106.1347
# 3        False      False       1073.549164    31767.13895
# 4        False      False       529.2506047    35704.49394
# 5        False      False       785.6558829    38463.49588
# 6        False       True       919.5885305    7491.558572
# 7        False      False       825.5133305    24905.22658
# 8        False       True       808.6675043    17600.45134
# 9        False      False       1161.057854    37468.52929
# 10       False      False               0.0    29275.26829
# 11       False       True               0.0    21871.07309
# 12       False       True       1220.583753    13268.56222
# 13       False      False        237.045114    28251.69534
# 14       False      False       606.7423433    44994.55585
# 15       False      False       1112.968401    23810.17405
# 16       False      False       286.2325601    45042.41304
# 17       False      False               0.0    50265.31235
# 18       False       True       527.5401841    17636.53962
# 19       False      False       485.9368642    61566.10612
# 20       False      False       1095.072735    26464.63139
# 21       False      False       228.9525496     50500.1822
# 22       False      False       954.2617928    32457.50908
# 23       False      False       1055.956605    51317.88308
# 24       False      False       641.9843888    30466.10326
# 25       False      False       773.2117245    34353.31431
# 26       False      False       855.0085225    25211.33216
# 27       False      False       642.9997385     41473.5118
# 28       False      False       1454.863272    32189.09495
# 29       False      False       615.7042766    39376.39462
# 30       False       True       1119.569353    16556.07021
# 31       False      False       494.8162288    54384.78284
# 32       False       True       448.8806563    15799.47041
# 33       False       True       584.9048947    22429.93505
# 34       False      False       913.5871726     46907.2254
# 35       False       True       1423.938917    22634.48809
# 36       False       True       1499.724657    13190.65272
# 37       False      False       692.0341671    47806.61177
# 38       False      False       351.4534715    35087.48865
# 39       False      False       742.6276208    37864.82394
# 40       False      False       653.1184001     39489.5947
# 41       False      False       872.1386795    41787.56727
# 42       False      False       837.2626228    51471.77209
# 43       False      False       1151.630566    42917.46956
# 44       False       True       220.5556084    16872.94756
# 45       False       True        1690.23441    19052.57222
# 46       False      False       408.7729143    54206.93921
# 47       False      False       1238.610321    50066.68053
# 48       False      False        1228.30835    37408.50387
# 49       False      False       820.9192041    47746.54207
# 50       False      False       857.4851178    31688.34597
# 51       False      False       563.6181772    42641.25327
# 52       False       True       1282.972534    13120.63647
# 53       False       True       1505.782675    26557.14145
# 54       False       True       904.0402591    16882.30061
# 55       False      False               0.0    49956.58057
# 56       False       True       1294.497347    10464.32073
# 57       False       True       1275.550633    15887.46849
# 58       False      False       1536.594601    48766.90746
# 59       False      False       1332.522644    39143.13707
# 60       False      False       492.0797678     33379.0946
# 61       False      False       766.2343793    46478.29426
# 62       False      False       690.1272462    63432.98425
# 63       False      False               0.0    32481.54005
# 64       False      False       1480.655309    36866.15707
# 65       False      False        989.055597    45344.25132
# 66       False      False       1302.341835    33695.42623
# 67       False      False       1044.552343    54696.76598
# 68       False      False               0.0    43658.22772
# 69       False      False       866.0284364    38363.42163
# 70       False      False       690.8007924    48140.47134
# 71       False      False        597.757142    31577.61513
# 72       False      False       429.4854023     51311.2181
# 73       False      False       1398.156201    39644.94219
# 74       False       True       1578.064099    19886.49395
# 75       False      False       857.0690531    26655.68897
# 76       False       True        752.459946    16211.27579
# 77       False       True        774.738427    15193.73314
# 78       False      False       728.3732513    45131.71826
# 79       False      False       76.99129053    28392.09341
# 80       False      False       196.4569131    41346.78591
# 81       False       True       948.7479184    14297.61905
# 82       False      False       431.9208853    39369.88156
# 83       False      False       461.6381822    46221.21149
# 84       False      False       572.0157602    33046.31296
# 85       False      False       335.5681447    51258.44423
# 86       False      False       510.2375932    60397.71865
# 87       False       True       1005.161306    24038.65204
# 88       False       True       162.4544511    13241.75206
# 89       False      False       932.5331557    50537.46565
# 90       False       True       893.3304676    11905.68179
# 91       False      False       1332.782564    44495.16276
# 92       False      False       1404.383069    35043.10603
# 93       False       True       1148.965139    16578.19212
# 94       False      False       368.2234257    57596.82584
# 95       False      False       449.4666288    45950.66672
# 96       False      False       820.0171126    51584.65732
# 97       False       True       619.7518686    15750.62208
# 98       False      False       1047.718124    46416.97099
# 99       False      False       243.8413283    47193.88813
# 100      False      False       186.5003869    45430.55027
# Rows: 1-100 | Columns: 4

# %% [markdown]
# The next step is to find and handle missing values. You can find missing data with `describe()`, which produces a summary of the dataset:
#
# ```python
# data.describe()
# ```

# %%
data.describe()
# Out:
#                       count                  mean                  std            min   \\
# "default"              7618    0.0336046206353373    0.180221013322029            0.0   \\
# "student"              7618     0.293646626411131    0.455461871265586            0.0   \\
# "credit_balance"       7618      834.003369570169      482.06106444258            0.0   \\
# "income"               7618       33495.347920566     13302.1082548578    771.9677294   \\
#                             approx_25%          approx_50%          approx_75%   \\
# "default"                          0.0                 0.0                 0.0   \\
# "student"                          0.0                 0.0                 1.0   \\
# "credit_balance"          481.06857144    819.768457383333       1164.03911975   \\
# "income"              21269.7813009091    34558.1724415385    43731.6383822222   \\
#                               max
# "default"                     1.0
# "student"                     1.0
# "credit_balance"      2502.684931
# "income"               73554.2335
# Rows: 1-4 | Columns: 9

# %% [markdown]
# The `count` shows that all columns (`default`, `student`, `credit_balance`, `income`) have the same number of values, so there are no missing values in the dataset.

# %% [markdown]
# <a id='h2_cell'></a>
# ### Data Exploration

# %% [markdown]
# A graph is often useful for identifying trends. Create a scatter plot for income, balance, and the `default` category:
#
# ```python
# data.scatter(['credit_balance','income'],catcol='default')
# ```

# %%
data.scatter(['credit_balance','income'],catcol='default')
# Out:
# <AxesSubplot: xlabel='"credit_balance"', ylabel='"income"'>

# %% [markdown]
# An obvious correlation is higher balances and defaults, but there is also a less obvious correlation with income. This correlation is easier to see with some other graphs:
#
# ```python
# data["credit_balance"].boxplot(by = "default")
#
# data["income"].boxplot(by = "default")
# ```

# %%
data["credit_balance"].boxplot(by = "default")

data["income"].boxplot(by = "default")
# Out:
# <AxesSubplot: xlabel='"default"', ylabel='"income"'>

# %%
data.bar(['default'])
# Out:
# <AxesSubplot: xlabel='Density', ylabel='"default"'>

# %%
data.bar(['student','default'])
# Out:
# <AxesSubplot: xlabel='Density', ylabel='"student"'>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Knowledge Check:</b> What kind of classification problem is predicting the winner of a football match?
# </div>

# %%
Q1 = create_multipleChoice_widget(['Binary','Multi-class'],'Binary')

# %%
display(Q1)
# Out:
# VBox(children=(Output(), RadioButtons(options=(('Binary', 0), ('Multi-class', 1)), value=0), Button(descriptio…

# %% [markdown]
# ***

# %% [markdown]
# <a id='h3_cell'></a>
# ### Applying logistic regression

# %% [markdown]
# Import the `LogisticRegression` library and create a logistic regression model object:
#
# ```python
# from verticapy.learn.linear_model import LogisticRegression
# model = LogisticRegression("public.LR_default")
# ```
#
# Fit the model with the data:
#
# ```python
# model.fit(data, ["credit_balance", "income","student"], "default")
# ```

# %%
from verticapy.learn.linear_model import LogisticRegression
model = LogisticRegression("public.LR_default")

# %%
model.fit(data, ["credit_balance", "income","student"], "default")
# Out:
# =======
# details
# =======
#   predictor   |coefficient|std_err | z_value |p_value
# --------------+-----------+--------+---------+--------
#   Intercept   | -11.15139 | 0.57746|-19.31113| 0.00000
# credit_balance|  0.00587  | 0.00027|21.60061 | 0.00000
#     income    |  0.00001  | 0.00001| 0.63721 | 0.52399
#    student    | -0.60562  | 0.27726|-2.18431 | 0.02894
#
#
# ==============
# regularization
# ==============
# type| lambda
# ----+--------
# none| 1.00000
#
#
# ===========
# call_string
# ===========
# logistic_reg('public.LR_default', '"public"."_verticapy_tmp_view_dbadmin_6064_718428356_"', '"default"', '"credit_balance", "income", "student"'
# USING PARAMETERS optimizer='newton', epsilon=1e-06, max_iterations=100, regularization='none', lambda=1, alpha=0.5, fit_intercept=true)
#
# ===============
# Additional Info
# ===============
#        Name       |Value
# ------------------+-----
#  iteration_count  |  8
# rejected_row_count|  0
# accepted_row_count|7618

# %% [markdown]
# As shown in fitted model, the p-value for `credit_balance` and `student` are both low, but the p-value for `income` is quite high (that is, greater than 0.05). A high p-value indicates that the predictor, `income`, has little or no effect on the outcome, the likelihood that a person will default.
#
# The `credit_balance` coefficient is positive, suggesting that the greater a person's balance, the more likely it is that they default. On the other hand, the coefficient for `student` is negative, which suggests that being is a student reduces the probability that a person will default.
#
# You can check the accuracy of the model by scoring it against some accuracy metrics. Vertica supports [many metrics](https://www.vertica.com/python/documentation_last/learn/Model/binary_classification_score/), but for simplicity, this example will only concern the following:
#
# - Accuracy
# - Area Under the Curve (AUC)
# - Precision
# - Specificity
#
# ```python
# model.score(method="accuracy")
# model.score(method="auc")
# model.score(method="precision")
# model.score(method="specificity")
# ```

# %%
print('Accuracy:',model.score(method="accuracy"))
print('AUC:',model.score(method="auc"))
print('Precision:',model.score(method="precision"))
print('Specificity:',model.score(method="specificity"))
# Out:
# Accuracy: 0.9726962457337884
# AUC: 0.9522890455209175
# Precision: 0.7105263157894737
# Specificity: 0.9955175224123879

# %% [markdown]
# The model's accuracy, AUC, and specificity are quite good, but its precision is somewhat lacking because the data is a bit skewed. That is, the dataset contains significantly more non-defaulters than defaulters. This imbalance is shown in the graph below:
#
# ```python
# data.bar(['default'])
# data["default"].topk()
# ```

# %%
data.bar(['default'])
# Out:
# <AxesSubplot: xlabel='Density', ylabel='"default"'>

# %%
data["default"].topk()
# Out:
#            count    percent
# False       7362      96.64
# True         256       3.36
# Rows: 1-2 | Columns: 3

# %% [markdown]
# One solution to this problem is to balance the data with `balance()` with the `under` method to allow more from the category with more data points (cases where the individual does not default), otherwise the dataset will only contain 256 values to train from.
#
# You can tweak the ratio (x) to ensure that the defaulters are properly represented in the balanced dataset:
#
# ```python
# balanced_data=data.balance(column="default",method="under",x=0.25)
# balanced_data["default"].topk()
# ```

# %%
balanced_data=data.balance(column="default",method="under",x=0.25)

# %%
balanced_data["default"].topk()
# Out:
#            count    percent
# False       1025     80.016
# True         256     19.984
# Rows: 1-2 | Columns: 3

# %% [markdown]
# Let us train again to see if we improved.

# %%
model.fit(balanced_data, ["credit_balance", "income","student"], "default")
# Out:
# =======
# details
# =======
#   predictor   |coefficient|std_err | z_value |p_value
# --------------+-----------+--------+---------+--------
#   Intercept   | -8.87974  | 0.73503|-12.08072| 0.00000
# credit_balance|  0.00589  | 0.00038|15.51593 | 0.00000
#     income    | -0.00000  | 0.00001|-0.10420 | 0.91701
#    student    | -0.90451  | 0.37083|-2.43915 | 0.01472
#
#
# ==============
# regularization
# ==============
# type| lambda
# ----+--------
# none| 1.00000
#
#
# ===========
# call_string
# ===========
# logistic_reg('public.LR_default', '"public"."_verticapy_tmp_view_dbadmin_6064_7892778534_"', '"default"', '"credit_balance", "income", "student"'
# USING PARAMETERS optimizer='newton', epsilon=1e-06, max_iterations=100, regularization='none', lambda=1, alpha=0.5, fit_intercept=true)
#
# ===============
# Additional Info
# ===============
#        Name       |Value
# ------------------+-----
#  iteration_count  |  7
# rejected_row_count|  0
# accepted_row_count|1281

# %%
print('Accuracy:',model.score(method="accuracy"))
print('AUC:',model.score(method="auc"))
print('Precision:',model.score(method="precision"))
print('Specificity:',model.score(method="specificity"))
# Out:
# Accuracy: 0.9039812646370023
# AUC: 0.951080411585369
# Precision: 0.7854077253218884
# Specificity: 0.9512195121951219

# %% [markdown]
# The balanced dataset improved the model's precision at the cost of accuracy. There is always going to be trade-off when working with imbalanced data.

# %% [markdown]
# ***

# %% [markdown]
# <font style="font-family:Calibri"> Author Name: Umar Farooq Ghumman
# <br>
# Author Contact: umarfarooq.ghumman@vertica.com</font>
